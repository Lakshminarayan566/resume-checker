# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshminarayan566/resume-checker/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf_path = "/content/M.Lucky(1).pdf"
text = extract_text_from_pdf(pdf_path)

print(text)
# Out:
# MARIDI LAKSHMI NARAYANA
# Student of AI&ML
# phone: 9704592449 | Email: luckymaridis@gmail.com | Location: Bhimavarm, Andhra Pradesh
# ABOUT ME
# EDUCATION
# VISHNU INSTITUTE OF
# TECHNOLOGY,BHIMAVARAM
# Bachelor of Technology
# course:AI&ML CGPA: 8.7
# 2024-2027
# LANGUAGESTECHNICAL SKILLSPROJECTS
# NPTEL COURSESACHIEVEMENTSCourse: MPC
# Percentage: 97.1
# 2021-2023
# HTML & CSS
# Java Script
# Python
# OOPS through Java
# MySQL,CQL
# Basics of React.js &
# Node.js
# Algorithm Analysis
# Machine Learning
# Database Management Systems
# Programming in Java
# Machine Learning Applications for Engineering
# and SciencesDeveloped a heart disease prediction model using
# ML techniques with key risk factor analysis and
# optimized data processing for accurate early
# diagnosis.
# Developed an AI-powered agricultural advisory
# system using Flask, Scikit-learn, and TensorFlow to
# provide data-driven farming recommendations for
# ...

# %%
from google import genai
client = genai.Client(api_key="AIzaSyBLBfg5zADhf2_xFLTs7esTIDoS6raviEc")

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=f'here is the context:{text} question: give rate about my resume 100'
)

print(response.text)
# Out:
# Okay, let's break down your resume and give it a rating out of 100.
#
# **Overall Rating: 78/100**
#
# You have a very solid foundation, especially with your projects and technical skills. A few key tweaks can significantly boost your resume's impact.
#
# ---
#
# **Strengths:**
#
# 1.  **Strong "ABOUT ME" Section:** It clearly defines your aspirations, combines your interests (web dev + AI/ML), highlights key skills, and states your objective (internship). This is excellent.
# 2.  **Excellent Project Descriptions:** This is your strongest section!
#     *   You use strong action verbs ("Developed").
#     *   You clearly state the purpose/impact (early diagnosis, improved crop yield, seamless communication).
#     *   Crucially, you mention specific technologies used (Flask, Scikit-learn, TensorFlow, WebRTC, Socket.io, Node.js). This is fantastic for a technical resume.
# ...

# %%
def resume_parser(input):
  prompt=f"""
  your resume parser
  Extract:
  -Executive Summary
  -Skills
  -Education
  -Tools & Techonolgies
  -Experience Summary

  Resume:
  {input}
  return in bullet points
  """
  response = client.models.generate_content(
          model = "gemini-2.5-flash",
          contents = prompt
  )
  return response.text

lucky = resume_parser(text)
print(lucky)
# Out:
# Here is the extracted information from the resume:
#
# **-Executive Summary**
# *   Aspiring Web Developer and AIML Engineering student with a strong foundation in HTML, CSS, and JavaScript.
# *   Passionate about building responsive and dynamic websites while exploring the intersection of web development and AI/ML technologies.
# *   Quick learner with problem-solving skills, eager to gain hands-on experience through an internship and contribute to real-world web projects.
#
# **-Skills**
# *   HTML & CSS
# *   JavaScript
# *   Python
# *   OOPS through Java
# *   MySQL, CQL
# *   Basics of React.js & Node.js
# *   Algorithm Analysis
# *   Machine Learning
# *   Database Management Systems
# *   Programming in Java
# *   Machine Learning Applications for Engineering and Sciences
# *   Telugu
# *   Hindi
# *   English
#
# **-Education**
# *   **VISHNU INSTITUTE OF TECHNOLOGY, BHIMAVARAM**
#     *   Bachelor of Technology (AI&ML)
#     *   CGPA: 8.7
#     *   2024-2027
# ...

# %%
def ats_match(parsed_resume, parsed_jd):
    prompt = f"""
You are an Applicant Tracking System.

Compare the resume and job description.

Resume:
{parsed_resume}

Job Description:
{parsed_jd}

Provide:
1. Match percentage (0-100)
2. Matching skills
3. Missing skills
4. Strengths
5. Improvement suggestions
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# %%
ats_result = ats_match(lucky, luckyy)

print("===== ATS MATCH RESULT =====")
print(ats_result)
# Out:
# ===== ATS MATCH RESULT =====
# It appears the 'Job Description' provided is identical to the 'Resume' information. This means I cannot perform a comparative analysis between a unique job requirement and a candidate's profile as an Applicant Tracking System normally would.
#
# However, if we treat the provided 'Job Description' as an *ideal candidate profile* that the applicant *already perfectly matches* (since the content is identical), here is the analysis based on that premise:
#
# ---
#
# ### ATS Analysis: Resume vs. (Identical) Job Description
#
# **1. Match Percentage:**
# **100%**
# (The provided Job Description is identical to the Resume content.)
#
# **2. Matching Skills:**
# All skills listed in the resume are considered a perfect match as they are also present in the identical "Job Description."
# *   HTML & CSS
# *   JavaScript
# *   Python
# *   OOPS through Java
# *   MySQL, CQL
# *   Basics of React.js & Node.js
# *   Algorithm Analysis
# *   Machine Learning
# ...
